# %% [markdown]
# <h1>Redes neuronales</h1>
# <p>son una estructura que se inspira en comno funciona el cerebro humano y es muy utilizado para machine learning debido a los resultados que se pueden obtener, que es aplicable a todo tipo de problemas.</p>
#
# <p><b>perceptron:</b> es un concepto simple el cual permite tomar decisiones interesantes</p>
# ![image.png](attachment:image.png)
# <p>en la imagen anterior se toma como ejemplo si vamos a ir a un concierto y esto depende de tres factores el clima, si hay dinbero y si iran tus amigos</p>
# ![image-2.png](attachment:image-2.png)
# <p>si la respuesta es <b>SI</b> el valor será de <b>1</b> pero si es un <b>NO<b> será <b>0</b> </p>
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# <p>esto dará la respuesta  1 si vamos y 0 si no vamos </p>
# ![image-5.png](attachment:image-5.png)
# <p>dentro del circulo se tiene un número el cual se ajusta y el cual tiene como nombre <b>umbral</b> este circulo revisará si la suma de todas las entradas es > al umbral si si es 1 si no es 0 </p>
# ![image-6.png](attachment:image-6.png)
# <p>si se tiene un umbral de 1 y se dice que si el clima es agradable e iran tus amigos pero no tienes dinero, esto lo que harpa es comparar el umbral ya que se tiene que  tanto el clima y la ida de los amigos se suman da un número de dós y si se compara y se evidencia que el umbral es menor que las respuestas por lo tanto si irá al concierto, es decis si 2>1 entonces iré al concierto, de lo contrarío no iré </p>
# ![image-7.png](attachment:image-7.png)
# <p>si  en el caso que tiene dinero y van tus amigos pues en este casi támbién iras al concierto</p>
#
# ![image-8.png](attachment:image-8.png)
# <p>ahora si existe algo que debe super poner esto, se debe entender como el peso, es decir si no quieres mojarte por el que el clima no es agradable tomará un peso mucho mayor </p>
# ![image-9.png](attachment:image-9.png)
