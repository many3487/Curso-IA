# %% [markdown]
# Sirve para encontrar patrones en las imagenes y poder entenderlas
#
#
# cfiltro: o kernel : sirve para tomar una imagen hacer ina transformación en ella
#
#
# ![image.png](attachment:image.png)
#
#
# las redes neuronales convolucionales la particularidad qu tienen es que no solo ajuntan pesos y sesgos durante su optimización si no que al crearlo se le especifica que se quiere uzar cierto número de filtros y el proceso ajusta los numeros de la celda de los filtros como si fuera un cesgo o filtro
#
#
#
# agrupación
#
# si se crear una red para crear perros o gatos la entrada son los pixeles de la imagen
# se especifica la capa convolucional y  luego le decimos cuantos filtros queremos que aprenda en cada capa
#
# luego se le puede agregar una capa de agrupación la cual toma la imagen que sale de cada uno de los filtros y la hace más pequeña resaltando los pixeles con más valor
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
#
# ejemplo con numeros
# ![image-4.png](attachment:image-4.png)
